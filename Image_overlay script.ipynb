# %%
import cv2
import sys 
import random as rand

# %%
import numpy as np
import scipy.misc as ms
import matplotlib.pyplot as plt
from PIL import Image

# %%
import os
os.listdir()
# Out:
# ['augmented_train',
#  'Untitled-Copy1.ipynb',
#  'LLD-logo_sample',
#  'LLD-logo_files.zip',
#  'KNN_weighted_mean.py',
#  'LLD-logo-files',
#  'fresh_celeb_list.txt',
#  'VGG_TransferLearning_ASL.ipynb',
#  'KNN.py',
#  'LLD-logo_metadata.pkl',
#  'Untitled1.ipynb',
#  'Programs',
#  'asl-alphabet.zip',
#  'augmented_test',
#  '__pycache__',
#  '.ipynb_checkpoints',
#  'asl-alphabet',
#  'unknown_db_celeb.pkl',
#  'readme.txt',
#  'datasets',
#  'Untitled.ipynb',
#  'known_db_celeb.pkl',
#  'Linear_VS_KNN.ipynb',
#  'hand_recognition']

# %%
def get_images_dr(dr):
    a=os.listdir(dr)
    images=[]
    for img in a:
        im=os.listdir(dr+"/"+img)
        im=[dr+"/"+img+"/"+i for i in im]
        images.extend(im)
    return images

# %%
hand_symbols_train=get_images_dr("asl-alphabet/asl_alphabet_train")

# %%
len(hand_symbols_train)
# Out:
# 87000

# %%
import pickle

# %%
logos=['LLD-logo-files'+"/"+i for i in os.listdir('LLD-logo-files')]

# %%
log_arr=np.array(Image.open(logos[9]))
hand_arr=np.array(Image.open(train_images[3]))

# %%
Image.open(logos[9])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x400 at 0x7F17060CAEB8>

# %%
log_arr=ms.imresize(log_arr,(10,10,3))
log_arr=ms.imresize(log_arr,(200,200,3))
# Out:
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
plt.imshow(log_arr)

# %%
log_arr.shape,hand_arr.shape
# Out:
# ((200, 200, 3), (200, 200, 3))

# %%
i=.8
log_arr=np.array(Image.open(logos[17493]))
hand_arr=np.array(Image.open(train_images[3]))
log_arr=ms.imresize(log_arr,(10,10,3))
log_arr=ms.imresize(log_arr,(200,200,3))
plt.imshow(cv2.addWeighted(hand_arr,i,log_arr,i,0))
# Out:
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """

# %%
os.mkdir("augmented_train")

# %%
for dr in os.listdir("asl-alphabet/asl_alphabet_train"):
    os.mkdir("augmented_train/"+dr)

# %%
train_images=get_images_dr("hand_recognition/data/train")
test_images=get_images_dr("hand_recognition/data/validation")

# %%
rand.choice(np.arange(0.6,0.8,.02))
# Out:
# 0.7600000000000001

# %%
def aug_save(path1,path2,save_dir):
    log_arr=np.array(Image.open(path1))
    hand_arr=np.array(Image.open(path2))
    log_arr=ms.imresize(log_arr,(10,10,3))
    log_arr=ms.imresize(log_arr,hand_arr.shape)
    r=rand.choice(np.arange(0.6,0.8,.02))
    result=cv2.addWeighted(hand_arr,r,log_arr,r,0)
    p="/".join(path2.split("/")[3:])
    ms.imsave(save_dir+p,result)

# %%
for i in range(len(train_images)):
    aug_save(logos[i],train_images[i],"augmented_train/")
# Out:
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   if __name__ == '__main__':

# %%
os.mkdir("augmented_test")
for dr in os.listdir("hand_recognition/data/validation"):
    os.mkdir("augmented_test/"+dr)

# %%
logos_test=logos[len(test_images):]
for i in range(len(test_images)):
    aug_save(logos_test[i],test_images[i],"augmented_test/")
# Out:
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """
# /home/deepak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   if __name__ == '__main__':
